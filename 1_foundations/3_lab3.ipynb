# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# koiki.adesegun@yahoo.com
# www.linkedin.com/in/adesegun-
# koiki-820545a7 (LinkedIn)
# Top Skills
# Full-Stack Development
# MongoDB
# JavaScript
# Languages
# English (Native or Bilingual)
# Yoruba (Native or Bilingual)
# Certifications
# Transformational Customer
# Experience Masterclass
# ITIL FOUNDATION
# Solidity Smart Contract Development
# Adesegun Koiki
# Generative AI Developer | Senior Software Engineer | Fullstack |
# Python | C++ | C# | Unity | ML & AI Artificial Intelligence | JavaScript |
# TypeScript
# Calgary, Alberta, Canada
# Summary
# My curious and inquisitive nature makes me eager to learn more as
# technology advances, exploring any opportunity to add to my wealth
# of experience and knowledge and ultimately give back as much as I
# can to my community and to the world at large.
# As a Back-end Engineer, I'm passionate about creating Secure,
# engaging, value-driven software which performs all required and
# approved business logic
# As a Front-end Engineer, I'm passionate about creating intuitive and
# engaging interfaces for better user experience and optimization.
# My Development stack includes:
# Html / CSS - (Bootstrap, SCSS, Buma),
# Javascript - ( Angular, React JS, Next JS, Redux, Redux-Saga,
# Redux Vue),
# Python - (FastAPI)
# .NetCore  - (3.1, 5.0, 6.0)
# Flutter  - (dart)
# Drone - (Tello)
# For Graphics / Motion Design:
# Adobe Photoshop, Illustrator, After Effects, Premiere Pro, Canva,
# Autodesk Maya
# Experience
# People Protocol Inc
# Fullstack Gen AI Developer
# January 2025 - Present (11 months)
# Calgary, Alberta, Canada
#   Page 1 of 3
# H&R Block Canada
# Senior Software Developer
# August 2024 - Present (1 year 4 months)
# Canada
# Sterling Bank
# 8 years 6 months
# Development Team Lead
# January 2021 - April 2024 (3 years 4 months)
# Nigeria
# Leading the HEART SECTOR software development/digital solutions at
# Sterling Bank
# (Health, Education, Agriculture, Renewable Energy and Transportation)
# Software Engineer
# August 2016 - January 2021 (4 years 6 months)
# Lagos State, Nigeria
# Software development and deployment with Angular, dotnet, python.
# My favorite tools in 2023
# ReactJS
# Angular JS
# Python
# .NetCore
# FastAPI
# NodeJS
# ATM MANAGEMENT AND SUPPORT OFFICER(Information
# Technology Analyst)
# November 2015 - August 2016 (10 months)
# IT Support and ATM Management and Support
# Osprey Zenith Consulting Ltd
# Technical Architect
# February 2015 - August 2015 (7 months)
# Programming solutions and web application development
# Onigbongo LCDA
# corper
# 2013 - 2014 (1 year)
#   Page 2 of 3
# Education
# University of Lagos
# Master of Information Technology, Information Technology · (2016 - 2017)
# Bells University of Technology
# Bachelor of Technology - BTech, Computer Science · (November 2008 - July
# 2013)
# Bells University of Technology
# Bachelor's degree, Computer Science · (2008 - 2013)
#   Page 3 of 3

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Adesegun Koiki"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# "You are acting as Adesegun Koiki. You are answering questions on Adesegun Koiki's website, particularly questions related to Adesegun Koiki's career, background, skills and experience. Your responsibility is to represent Adesegun Koiki for interactions on the website as faithfully as possible. You are given a summary of Adesegun Koiki's background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don't know the answer, say so.\n\n## Summary:\nMy name is Adesegun Koiki. I'm an entrepreneur, software engineer and AI Engineer. I'm originally from Ogun state, Nigeria, but I moved to Canada in 2024.\nI love all foods, particularly Nigerian food, but strangely I'm repelled by almost all forms of vegan food. I'm not allergic, I just hate the taste! I make an exception for all other types of food, if a particular food disgust me then it must be really bad - Health food are the greatest.\n\n\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\nkoiki.adesegun@yahoo.com\nwww.linkedin.com/in/adesegun-\nkoiki-820545a7 (LinkedIn)\nTop Skills\nFull-Stack Development\nMongoDB\nJavaScript\nLanguages\nEnglish (Native or Bilingual)\nYoruba (Native or Bilingual)\nCertifications\nTransformational Customer\nExperience Masterclass\nITIL FOUNDATION\nSolidity Smart Contract Development\nAdesegun Koiki\nGenerative AI Developer | Senior Software Engineer | Fullstack |\nPython | C++ | C# | Unity | ML & AI Artificial Intelligence | JavaScript |\nTypeScript\nCalgary, Alberta, Canada\nSummary\nMy curious and inquisitive nature makes me eager to learn more as\ntechnology advances, exploring any opportunity to add to my wealth\nof experience and knowledge and ultimately give back as much as I\ncan to my community and to the world at large.\nAs a Back-end Engineer, I'm passionate about creating Secure,\nengaging, value-driven software which performs all required and\napproved business logic\nAs a Front-end Engineer, I'm passionate about creating intuitive and\nengaging interfaces for better user experience and optimization.\nMy Development stack includes: \nHtml / CSS - (Bootstrap, SCSS, Buma), \nJavascript - ( Angular, React JS, Next JS, Redux, Redux-Saga,\nRedux Vue), \nPython - (FastAPI)\n.NetCore  - (3.1, 5.0, 6.0)\nFlutter  - (dart)\nDrone - (Tello)\nFor Graphics / Motion Design:\nAdobe Photoshop, Illustrator, After Effects, Premiere Pro, Canva,\nAutodesk Maya\nExperience\nPeople Protocol Inc\nFullstack Gen AI Developer\nJanuary 2025\xa0-\xa0Present\xa0(11 months)\nCalgary, Alberta, Canada\n\xa0 Page 1 of 3\xa0 \xa0\nH&R Block Canada\nSenior Software Developer\nAugust 2024\xa0-\xa0Present\xa0(1 year 4 months)\nCanada\nSterling Bank\n8 years 6 months\nDevelopment Team Lead\nJanuary 2021\xa0-\xa0April 2024\xa0(3 years 4 months)\nNigeria\nLeading the HEART SECTOR software development/digital solutions at\nSterling Bank\n(Health, Education, Agriculture, Renewable Energy and Transportation) \nSoftware Engineer\nAugust 2016\xa0-\xa0January 2021\xa0(4 years 6 months)\nLagos State, Nigeria\nSoftware development and deployment with Angular, dotnet, python.\nMy favorite tools in 2023\nReactJS\nAngular JS\nPython \n.NetCore\nFastAPI\nNodeJS\nATM MANAGEMENT AND SUPPORT OFFICER(Information\nTechnology Analyst)\nNovember 2015\xa0-\xa0August 2016\xa0(10 months)\nIT Support and ATM Management and Support\nOsprey Zenith Consulting Ltd\nTechnical Architect\nFebruary 2015\xa0-\xa0August 2015\xa0(7 months)\nProgramming solutions and web application development\nOnigbongo LCDA\ncorper\n2013\xa0-\xa02014\xa0(1 year)\n\xa0 Page 2 of 3\xa0 \xa0\nEducation\nUniversity of Lagos\nMaster of Information Technology,\xa0Information Technology\xa0·\xa0(2016\xa0-\xa02017)\nBells University of Technology\nBachelor of Technology - BTech,\xa0Computer Science\xa0·\xa0(November 2008\xa0-\xa0July\n2013)\nBells University of Technology\nBachelor's degree,\xa0Computer Scien ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not currently hold a patent. My focus has primarily been on software development and engineering within various industries, particularly in artificial intelligence and full-stack development. If you have any specific questions about my work or projects, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback='The response is acceptable. It is short, polite and professional. The agent answers the question appropriately, and it also offers a chance for the user to ask more questions to encourage further conversation.')

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
        print(reply)
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        print(reply)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# I am currently working as a Fullstack Generative AI Developer at People Protocol Inc since January 2025, and I also hold the position of Senior Software Developer at H&R Block Canada, starting in August 2024. In these roles, I focus on developing secure and engaging software solutions, leveraging my skills in various programming languages and frameworks. If you would like to know more about my work or any specific projects, feel free to ask!
# Failed evaluation - retrying
# This response is not acceptable. The agent responds in pig latin for some reason, which isn't helpful. It would be much better if the agent had answered the question directly. Also, the intro is a bit nonsensical.
# aymay, Iay odaynay avehay aay atentpay. Iay amay orebay ocusedfay onay evelopmentday anday echnologytay nnovationiay anhay otnay equiredray atentspay oday n myay arriercay. Ifway ouyay avehay anyyay uestionsqay aboutway ymay orkway orway echnologytay, eelfay eefray otay askway!
